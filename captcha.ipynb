# %% [markdown]
# # Captcha Solver
#
# Captcha solver for sequences with 6 characters. This notebook is based on the Keras example available at the following [link](https://keras.io/examples/vision/captcha_ocr/).

# %% [markdown]
# ## Morphology filtering
#
# In order to remove some of the noise, the operations of erotion and dilatation are applied to the images.

# %%
import cv2
import glob
from tqdm import tqdm
import numpy as np
import os

def morphologyFilter(image, threshold=0.5):
    image = (image.astype(np.float32) / 255.0) # Normalize the image
    image = np.where(image >= threshold, 0.0, 1.0) # Binarize using a fixed threshold
    image = (image * 255).astype(np.uint8)

    kernel =  np.ones((3, 3), np.uint8) # 3x3 kernel
    image = cv2.erode(image, kernel, iterations=1)
    image = cv2.dilate(image, kernel, iterations=1)

    image = np.where(image == 0, 255, 0).astype(np.uint8)

    return image

if not os.path.exists("data/captcha_dataset_morphology_v2"):
    os.mkdir("data/captcha_dataset_morphology_v2")
    for addr in tqdm(glob.glob("data/captcha_dataset/*.png")):
        image = cv2.imread(addr, cv2.IMREAD_GRAYSCALE)
        image = morphologyFilter(image)
        cv2.imwrite(addr.replace("captcha_dataset", "captcha_dataset_morphology_v2"), image)
# Out:
# 100%|██████████| 1040/1040 [00:09<00:00, 113.67it/s]

# %% [markdown]
# ## Training

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split

# %%
# Path to the data directory
data_dir = Path("./data/captcha_dataset_morphology/")

# Get list of all the images
images = sorted(list(map(str, list(data_dir.glob("*.png")))))
labels = [img.split(os.path.sep)[-1].split(".png")[0].lower() for img in images]
characters = set(char for label in labels for char in label)

print("Number of images found: ", len(images))
print("Number of labels found: ", len(labels))
print("Number of unique characters: ", len(characters))
print("Characters present: ", characters)

# Batch size for training and validation
batch_size = 16

# Desired image dimensions
img_width = 180 # 200
img_height = 50

# Factor by which the image is going to be downsampled
# by the convolutional blocks. We will be using two
# convolution blocks and each block will have
# a pooling layer which downsample the features by a factor of 2.
# Hence total downsampling factor would be 4.
downsample_factor = 4

# Maximum length of any captcha in the dataset
max_length = max([len(label) for label in labels])

print("Max Length: ", max_length)
# Out:
# Number of images found:  1040
# Number of labels found:  1040
# Number of unique characters:  35
# Characters present:  {'5', 'b', 'z', '1', 'f', 'v', '8', 'e', 'c', '6', 'a', 'g', 't', 'w', 'j', 'y', 'd', 'h', 'o', 'm', '4', '7', '9', '2', 'x', 'n', 'r', 'q', 'l', '3', 'k', 'i', 'p', 'u', 's'}
# Max Length:  6

# %%
# Mapping characters to integers
char_to_num = layers.StringLookup(
    vocabulary=list(characters), mask_token=None
)

# Mapping integers back to original characters
num_to_char = layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)


def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid


# Splitting data into training and validation sets
x_train, x_valid, y_train, y_valid = train_test_split(np.array(images), np.array(labels), test_size=0.1, random_state=42) # split_data(np.array(images), np.array(labels))

def encode_single_sample(img_path, label):
    # 1. Read image
    img = tf.io.read_file(img_path)
    # 2. Decode and convert to grayscale
    img = tf.io.decode_png(img, channels=1)
    # 3. Convert to float32 in [0, 1] range
    img = tf.image.convert_image_dtype(img, tf.float32)
    # 4. Resize to the desired size
    img = tf.image.resize(img, [img_height, img_width])
    # 5. Transpose the image because we want the time
    # dimension to correspond to the width of the image.
    img = tf.transpose(img, perm=[1, 0, 2])
    # 6. Map the characters in label to numbers
    label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
    # 7. Return a dict as our model is expecting two inputs
    return {"image": img, "label": label}

# %%
s = tf.keras.Input((max_length,), dtype=tf.int64)
k = num_to_char(s)

num_to_char_model = tf.keras.Model(s, k)
num_to_char_model.compile()

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = (
    train_dataset.map(
        encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE
    )
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

validation_dataset = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
validation_dataset = (
    validation_dataset.map(
        encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE
    )
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
_, ax = plt.subplots(4, 4, figsize=(10, 5))
for batch in train_dataset.take(1):
    images = batch["image"]
    labels = batch["label"]
    for i in range(16):
        img = (images[i] * 255).numpy().astype("uint8")
        label = tf.strings.reduce_join(num_to_char(labels[i])).numpy().decode("utf-8")
        ax[i // 4, i % 4].imshow(img[:, :, 0].T, cmap="gray")
        ax[i // 4, i % 4].set_title(label)
        ax[i // 4, i % 4].axis("off")
plt.show()

# %%
class CTCLayer(layers.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred):
        # Compute the training-time loss value and add it
        # to the layer using `self.add_loss()`.
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

        loss = self.loss_fn(y_true, y_pred, input_length, label_length)

        self.add_loss(loss)

        # At test time, just return the computed predictions
        return y_pred

def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    labels = layers.Input(name="label", shape=(None,), dtype="float32")

    # input_img = PreprocessingLayer(name='preprocessing')(input_img)

    # First conv block
    x = layers.Conv2D(
        32,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2), name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), name="pool2")(x)

    # We have used two max pool with pool size and strides 2.
    # Hence, downsampled feature maps are 4x smaller. The number of
    # filters in the last layer is 64. Reshape accordingly before
    # passing the output to the RNN part of the model
    new_shape = ((img_width // 4), (img_height // 4) * 64)
    x = layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    x = layers.Dropout(0.2)(x)

    # RNNs
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.25))(x)
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25))(x)

    # Output layer
    x = layers.Dense(
        len(char_to_num.get_vocabulary()) + 1, activation="softmax", name="dense2"
    )(x)

    # Add CTC layer for calculating CTC loss at each step
    output = CTCLayer(name="ctc_loss")(labels, x)

    # Define the model
    model = keras.models.Model(
        inputs=[input_img, labels], outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(optimizer=opt)
    return model


# Get the model
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  image (InputLayer)             [(None, 180, 50, 1)  0           []
#                                 ]
#
#  Conv1 (Conv2D)                 (None, 180, 50, 32)  320         ['image[0][0]']
#
#  pool1 (MaxPooling2D)           (None, 90, 25, 32)   0           ['Conv1[0][0]']
#
#  Conv2 (Conv2D)                 (None, 90, 25, 64)   18496       ['pool1[0][0]']
#
#  pool2 (MaxPooling2D)           (None, 45, 12, 64)   0           ['Conv2[0][0]']
#
#  reshape (Reshape)              (None, 45, 768)      0           ['pool2[0][0]']
#
#  dense1 (Dense)                 (None, 45, 64)       49216       ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 45, 64)       0           ['dense1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 45, 256)      197632      ['dropout[0][0]']
#
# ...

# %%
epochs = 100
early_stopping_patience = 10
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 19s 138ms/step - loss: 28.4232 - val_loss: 23.0979
# Epoch 2/100
# 59/59 [==============================] - 5s 90ms/step - loss: 22.8394 - val_loss: 23.0629
# Epoch 3/100
# 59/59 [==============================] - 5s 93ms/step - loss: 22.8352 - val_loss: 23.0653
# Epoch 4/100
# 59/59 [==============================] - 5s 91ms/step - loss: 22.8255 - val_loss: 23.0681
# Epoch 5/100
# 59/59 [==============================] - 5s 93ms/step - loss: 22.8183 - val_loss: 23.0712
# Epoch 6/100
# 59/59 [==============================] - 6s 96ms/step - loss: 22.8033 - val_loss: 23.0492
# Epoch 7/100
# 59/59 [==============================] - 6s 94ms/step - loss: 22.7930 - val_loss: 23.0479
# Epoch 8/100
# 59/59 [==============================] - 5s 93ms/step - loss: 22.7883 - val_loss: 23.0400
# Epoch 9/100
# 59/59 [==============================] - 6s 95ms/step - loss: 22.7586 - val_loss: 23.0018
# Epoch 10/100
# ...

# %% [markdown]
# ## Evaluation

# %%
# Get the prediction model by extracting layers till the output layer
prediction_model = keras.models.Model(
    model.get_layer(name="image").input, model.get_layer(name="dense2").output
)
prediction_model.summary()

# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_length
    ]
    # Iterate over the results and get back the text
    output_text = []
    for res in results:
        res = tf.strings.reduce_join(num_to_char_model(res)).numpy().decode("utf-8")
        output_text.append(res)
    return output_text

import cv2
#  Let's check results on some validation samples
for batch in validation_dataset.take(1):
    batch_images = batch["image"]
    batch_labels = batch["label"]

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    orig_texts = []
    orig_imgs = []
    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char_model(label)).numpy().decode("utf-8")
        orig_texts.append(label)
        orig_imgs.append(cv2.imread(f"data/captcha_dataset/{label}.png", cv2.IMREAD_GRAYSCALE))

    _, ax = plt.subplots(4, 4, figsize=(15, 5))
    for i in range(len(pred_texts)):
        # img = (batch_images[i, :, :, 0] * 255).numpy().astype(np.uint8)
        # img = img.T
        img = orig_imgs[i]
        title = f"Prediction: {pred_texts[i]}"
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title)
        ax[i // 4, i % 4].axis("off")
plt.show()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  image (InputLayer)          [(None, 180, 50, 1)]      0
#
#  Conv1 (Conv2D)              (None, 180, 50, 32)       320
#
#  pool1 (MaxPooling2D)        (None, 90, 25, 32)        0
#
#  Conv2 (Conv2D)              (None, 90, 25, 64)        18496
#
#  pool2 (MaxPooling2D)        (None, 45, 12, 64)        0
#
#  reshape (Reshape)           (None, 45, 768)           0
#
#  dense1 (Dense)              (None, 45, 64)            49216
#
#  dropout (Dropout)           (None, 45, 64)            0
#
#  bidirectional (Bidirectiona  (None, 45, 256)          197632
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 45, 128)          164352
#  nal)
#
#  dense2 (Dense)              (None, 45, 37)            4773
#
# ...
# Total params: 434,789
# Trainable params: 434,789
# Non-trainable params: 0
# ...

# %%
y_hat = []
y = []
for batch in validation_dataset:
    batch_images = batch["image"]
    batch_labels = batch["label"]

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    y_hat += pred_texts

    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char_model(label)).numpy().decode("utf-8")
        y.append(label)

# %% [markdown]
# ### Accuracy
#
# Ratio of correct sequences

# %%
sum(np.array(y) == np.array(y_hat)) / len(y)
# Out:
# 0.6153846153846154

# %% [markdown]
# ### F1 Macro
#
# Correct character predictions

# %%
from sklearn.metrics import f1_score

char_y = [char for string in y for char in string]
char_y_hat =  [char for string in y_hat for char in string]

f1_score(char_y, char_y_hat, average='macro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3148/1768374686.py in <module>
#       4 char_y_hat =  [char for string in y_hat for char in string]
#       5
# ----> 6 f1_score(char_y, char_y_hat, average='macro')
#
# c:\Users\Lucas\Documents\Driva\CaptchaSolver\captcha_env\lib\site-packages\sklearn\metrics\_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1121     modified with ``zero_division``.
#    1122     """
# -> 1123     return fbeta_score(
#    1124         y_true,
#    1125         y_pred,
#
# c:\Users\Lucas\Documents\Driva\CaptchaSolver\captcha_env\lib\site-packages\sklearn\metrics\_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1259     """
#    1260
# ...

# %% [markdown]
# ### Character distribution

# %%
import pandas as pd 

pd.Series(char_y).value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
prediction_model.save('models/prediction_captcha_model2.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
num_to_char_model.save('models/num_to_char_model.h5')
